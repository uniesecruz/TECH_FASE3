# %% [markdown]
# # 2. Análise Exploratória dos Dados

# %%
from src.eda import plot_histogram, plot_boxplot
import pandas as pd

# Exemplo de análise de uma variável numérica
df_treino.info()
plot_histogram(df_treino, 'age', bins=30)
plot_boxplot(df_treino, y='age', x='income')
