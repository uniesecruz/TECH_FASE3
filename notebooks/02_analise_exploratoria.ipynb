# %% [markdown]
# # 2. Análise Exploratória dos Dados

# %%
from utils.eda import *
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = [8, 6]

# %%
# Ler a tabela delta e converter para o formato pandas
df_treino = spark.table("workspace.census_data.raw").toPandas()

# %%
import pandas as pd

# Supondo que o dataframe original se chame 'df'
# Converta as variáveis numéricas para int64:
numeric_vars = ['age', 'fnlwgt', 'education.num', 'capital.gain', 'capital.loss', 'hours.per.week']
df_treino[numeric_vars] = df_treino[numeric_vars].apply(pd.to_numeric, errors='coerce').astype('Int64')

# Converta as variáveis categóricas para object (string):
categorical_vars = ['workclass', 'education', 'marital.status', 
                    'occupation', 'relationship', 'race', 
                    'sex', 'native.country', 'income']

df_treino[categorical_vars] = df_treino[categorical_vars].astype(str)

# %% [markdown]
# ## 2.1 Variavel target

# %%
variavel = 'income'
analise_variavel_categorica(df_treino, variavel)
ax = df_treino[variavel].value_counts().plot.bar()
ax.set_title('Distribuição dos dados da variavel ' + variavel)
ax.set_ylabel('Numero de pessoas')
ax.set_xlabel('Class anual')
ax.set_xticklabels(labels=[' <=50K', ' >50K'])

# %% [markdown]
# ## 2.2 Variavel age

# %%
variavel = 'age'
analise_variavel_categorica(df_treino, variavel)
ax = df_treino[variavel].hist(bins=30)
ax.set_title('Distribuição dos dados da variavel ' + variavel)
ax.set_ylabel('Numero de pessoas')
ax.set_xlabel('Age')
plt.show()
sns.boxplot(y='age', x='income', data=df_treino)
plt.show()

# %% [markdown]
# ## 2.3 Variavel fnlwgt

# %%
variavel = 'fnlwgt'
analise_variavel_categorica(df_treino, variavel)
ax = df_treino[variavel].hist(bins=100)
ax.set_title('Distribuição dos dados da variavel ' + variavel)
ax.set_ylabel('Numero de pessoas')
ax.set_xlabel('fnlwgt')
plt.show()
sns.boxplot(y='fnlwgt', x='income', data=df_treino)
plt.show()

# %% [markdown]
# ## 2.4 Variavel education

# %%
variavel = 'education'
analise_variavel_continua(df_treino, variavel)
ax = df_treino[variavel].value_counts(normalize=True).plot.bar()
ax.set_title('Distribuição dos dados da variavel ' + variavel)
ax.set_ylabel('Porcentagem de pessoas')
ax.set_xlabel('Education')
ax.set_xticklabels(labels=[' HS-grad', ' Some-college', ' Bachelors', ' Masters', ' Assoc-voc', ' 11th', ' Assoc-acdm', ' 10th', ' 7th-8th', ' Prof-school', ' 9th', ' 12th', ' Doctorate', ' 5th-6th', ' 1st-4th', ' Preschool'])
plt.show()
print('Porcentagem de pessoas com  HS-grad that makes >$50K/yr: ', len(df_treino[(df_treino['education']==' HS-grad') & (df_treino['income']==' >50K')])/len(df_treino)*100)
print('Porcentagem de pessoas com college degree que fazem >$50K/yr: ', len(df_treino[(df_treino['education']==' Some-college') & (df_treino['income']==' >50K')])/len(df_treino)*100)
print('Porcentagem de pessoas com bachelors que fazem  >$50K/yr: ', len(df_treino[(df_treino['education']==' Bachelors') & (df_treino['income']==' >50K')])/len(df_treino)*100)
print('Porcentagem de pessoas com doctorate degree que fazem  >$50K/yr: ', len(df_treino[(df_treino['education']==' Doctorate') & (df_treino['income']==' >50K')])/len(df_treino)*100)
display(pd.crosstab([df_treino['education']], df_treino['income'], normalize='index'))
pd.crosstab([df_treino['education']], df_treino['income'], normalize='index').plot.bar()
plt.ylabel('Porcentagem de pessoas  (Normalizado pela income)')

# %% [markdown]
# ## 2.5 Variavel relationship

# %%
variavel = 'relationship'
analise_variavel_continua(df_treino, variavel)
ax = df_treino[variavel].value_counts(normalize=True).plot.bar()
ax.set_title('Distribuição dos dados da variavel ' + variavel)
ax.set_ylabel('Porcentagem de pessoas')
ax.set_xlabel('relationship')
ax.set_xticklabels(labels=[' Husband', ' Not-in-family', ' Own-child', ' Unmarried', ' Wife', ' Other-relative'])
plt.show()
display(pd.crosstab([df_treino['relationship']], df_treino['income'], normalize='index'))
pd.crosstab([df_treino['relationship']], df_treino['income'], normalize='index').plot.bar()
plt.ylabel('Porcentagem de pessoas  (Normalizado pela income)')

# %%
variavel='race'
analise_variavel_categorica(df_treino, variavel)

##plot distribution
ax=df_treino[variavel].value_counts(normalize=True).plot.bar()
ax.set_title('Distribuição dos dados da variavel '+variavel)
ax.set_ylabel('Percentagem de people')
ax.set_xlabel('Race')
ax.set_xticklabels(labels=[' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo', ' Other'])
plt.show()

display(pd.crosstab([df_treino['race']], df_treino['income'], normalize='index'))

pd.crosstab([df_treino['race']], df_treino['income'], normalize='index').plot.bar()
plt.ylabel('Porcentagem de pessoas  (normalizado pela income)')

# %%
variavel='sex'
analise_variavel_categorica(df_treino, variavel)

##Plot de distribuição
ax=df_treino[variavel].value_counts(normalize=True).plot.bar()
ax.set_title('Distribuição dos dados da variavel '+variavel)
ax.set_ylabel('Percentagem de people')
ax.set_xlabel('sex')
ax.set_xticklabels(labels=[' Male', ' Female'])
plt.show()

display(pd.crosstab([df_treino['sex']], df_treino['income'], normalize='index'))

pd.crosstab([df_treino['sex']], df_treino['income'], normalize='index').plot.bar()
plt.ylabel('Porcentagem de pessoas  (normalizado pela income)')

# %%
variavel='capital-gain'
analise_variavel_continua(df_treino, variavel)

ax=df_treino[variavel].hist(bins=50)
ax.set_title('Distribuição de dados da variavel '+variavel)
ax.set_ylabel('Numero de pessoas')
ax.set_xlabel('Capital gain')
plt.show()

sns.boxplot(y='capital-gain', x='income', data=df_treino)
plt.show()

# %% [markdown]
# ### 2.6 Análise das variáveis categóricas
#
# Nesta etapa, vamos analisar as variáveis categóricas do dataset, verificando a distribuição de frequências, cardinalidade e possíveis valores ausentes ou inconsistentes.

# %%
# Selecionar colunas categóricas
cat_cols = df_treino.select_dtypes(include=['object']).columns.tolist()

# Exibir distribuição de frequências para cada variável categórica
for col in cat_cols:
    print(f'\nDistribuição de {col}:')
    display(df_treino[col].value_counts(dropna=False))
    print(f'Cardinalidade: {df_treino[col].nunique()}')

# %% [markdown]
# ### 2.7 Análise das variáveis numéricas
#
# Agora, vamos analisar as variáveis numéricas, observando estatísticas descritivas, distribuição, outliers e possíveis valores ausentes.

# %%
# Selecionar colunas numéricas
num_cols = df_treino.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Estatísticas descritivas
print('Estatísticas descritivas das variáveis numéricas:')
display(df_treino[num_cols].describe())

# Verificar valores ausentes
print('\nValores ausentes por variável numérica:')
display(df_treino[num_cols].isnull().sum())

# %% [markdown]
# ### 2.8 Visualização das distribuições das variáveis numéricas
#
# Vamos visualizar as distribuições das variáveis numéricas utilizando histogramas e boxplots para identificar padrões, assimetrias e possíveis outliers.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogramas
for col in num_cols:
    plt.figure(figsize=(8, 4))
    sns.histplot(df_treino[col], kde=True, bins=30)
    plt.title(f'Histograma de {col}')
    plt.xlabel(col)
    plt.ylabel('Frequência')
    plt.show()

# Boxplots
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_treino[num_cols], orient='h')
plt.title('Boxplot das variáveis numéricas')
plt.show()

# %% [markdown]
# ### 2.9 Visualização das distribuições das variáveis categóricas
#
# Vamos visualizar as distribuições das variáveis categóricas utilizando gráficos de barras para facilitar a análise das frequências de cada categoria.

# %%
# Gráficos de barras para variáveis categóricas
for col in cat_cols:
    plt.figure(figsize=(10, 4))
    sns.countplot(data=df, x=col, order=df[col].value_counts().index)
    plt.title(f'Distribuição de {col}')
    plt.xlabel(col)
    plt.ylabel('Contagem')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# ### 2.10 Análise bivariada: relação entre variáveis numéricas e a variável alvo
#
# Vamos investigar como as variáveis numéricas se relacionam com a variável alvo (`income`), utilizando boxplots e gráficos de violino.

# %%
# Boxplots e violin plots para variáveis numéricas vs. variável alvo
for col in num_cols:
    plt.figure(figsize=(10, 4))
    sns.boxplot(x='income', y=col, data=df)
    plt.title(f'Boxplot de {col} por income')
    plt.show()
    
    plt.figure(figsize=(10, 4))
    sns.violinplot(x='income', y=col, data=df)
    plt.title(f'Violin plot de {col} por income')
    plt.show()

# %% [markdown]
# ### 2.11 Análise bivariada: relação entre variáveis categóricas e a variável alvo
#
# Vamos analisar como as variáveis categóricas se relacionam com a variável alvo (`income`), utilizando gráficos de barras segmentados e tabelas de contingência.

# %%
# Gráficos de barras segmentados e tabelas de contingência
for col in cat_cols:
    plt.figure(figsize=(10, 4))
    sns.countplot(data=df, x=col, hue='income', order=df[col].value_counts().index)
    plt.title(f'Distribuição de {col} por income')
    plt.xlabel(col)
    plt.ylabel('Contagem')
    plt.xticks(rotation=45)
    plt.legend(title='income')
    plt.show()
    
    # Tabela de contingência
    print(f'Tabela de contingência para {col} e income:')
    display(pd.crosstab(df[col], df['income'], normalize='index'))

# %% [markdown]
# ### 2.12 Análise de correlação entre variáveis numéricas
#
# Vamos calcular e visualizar a matriz de correlação entre as variáveis numéricas para identificar possíveis relações lineares e multicolinearidade.

# %%
# Matriz de correlação
corr_matrix = df_treino[num_cols].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', square=True)
plt.title('Matriz de correlação entre variáveis numéricas')
plt.show()

# %% [markdown]
# #### 2.12.1 Análise de multicolinearidade
#
# Vamos identificar pares de variáveis numéricas altamente correlacionadas, o que pode indicar multicolinearidade e impactar modelos lineares.

# %%
# Identificar pares de variáveis altamente correlacionadas
threshold = 0.8
corr_pairs = corr_matrix.abs().unstack().sort_values(ascending=False)
high_corr = [(a, b, corr_matrix.loc[a, b]) for (a, b) in corr_pairs.index if a != b and abs(corr_matrix.loc[a, b]) > threshold]

print('Pares de variáveis com correlação acima de', threshold)
for a, b, corr in high_corr:
    print(f'{a} x {b}: {corr:.2f}')

# %% [markdown]
# #### 2.12.2 Considerações finais da análise exploratória
#
# Nesta etapa, sumarizamos os principais achados da análise exploratória, destacando possíveis problemas de qualidade dos dados, padrões relevantes e hipóteses para as próximas etapas do pipeline.
