# %% [markdown]
# # 1. Download e Carregamento dos Dados

# %%
# from src.data_loader import download_dataset, load_csv
# import os

# data_dir = os.path.join(os.getcwd(), "data")
# dataset_ref = 'uciml/adult-census-income'

# # Baixar o dataset do Kaggle
# # download_dataset(dataset_ref, data_dir)

# # Carregar o CSV
# csv_path = os.path.join(data_dir, 'adult.csv')
# columns = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income']
# df_treino = load_csv(csv_path, columns=columns)
# df_treino.head()

# %%
# Ler os dados do novo arquivo
df_treino = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("s3://storage-4715-1183-1570/raw")

# Salvar o DataFrame como uma nova tabela no catálogo
df_treino.write.mode("overwrite").option("overwrite", "true").saveAsTable("workspace.census_data.raw")
