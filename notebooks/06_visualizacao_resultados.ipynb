# %% [markdown]
# # 6. Visualização de Resultados e Conclusão

# %%
# Exemplo de visualização de métricas e matrizes de confusão
from src.utils import calc_performance_metrics, plot_confusion_matrix

# Supondo que y_test, y_pred_test_lr, y_pred_test_rf estejam definidos
calc_performance_metrics("Regressão Logística (Teste)", y_test, y_pred_test_lr)
plot_confusion_matrix("Regressão Logística (Teste)", y_test, y_pred_test_lr)

calc_performance_metrics("Random Forest (Teste)", y_test, y_pred_test_rf)
plot_confusion_matrix("Random Forest (Teste)", y_test, y_pred_test_rf)
